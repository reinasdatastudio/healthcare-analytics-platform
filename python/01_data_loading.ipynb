# %%
import pandas as pd
import sys
from pathlib import Path

# %%
sys.path.append(str(Path.cwd().parent))

from src.database import get_engine

# %%
engine = get_engine()

# %%
query = """
SELECT *
FROM ml_dataset;
"""

risk = pd.read_sql(query, engine)

# %%
risk.head()
risk.info()
risk.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5764 entries, 0 to 5763
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               5764 non-null   str
#  1   age              5764 non-null   float64
#  2   gender           5764 non-null   str
#  3   encounter_count  5764 non-null   int64
#  4   diabetes         5764 non-null   int64
#  5   hypertension     5764 non-null   int64
# dtypes: float64(1), int64(3), str(2)
# memory usage: 270.3 KB
#                age  encounter_count     diabetes  hypertension
# count  5764.000000      5764.000000  5764.000000   5764.000000
# mean     41.693616        58.037994     0.423317      0.218945
# std      24.276306        89.914341     0.494128      0.413567
# min       0.000000         1.000000     0.000000      0.000000
# 25%      21.000000        24.000000     0.000000      0.000000
# 50%      42.000000        35.000000     0.000000      0.000000
# 75%      60.000000        56.000000     1.000000      0.000000
# max     110.000000       818.000000     1.000000      1.000000

# %%
engine.dispose()
